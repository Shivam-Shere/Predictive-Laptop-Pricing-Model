# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv('laptop_data.csv')

# %%
df.head()
# Out:
#    Unnamed: 0 Company   TypeName  Inches                    ScreenResolution  \
# 0           0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1           1   Apple  Ultrabook    13.3                            1440x900
# 2           2      HP   Notebook    15.6                   Full HD 1920x1080
# 3           3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4           4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# ...

# %%
df.shape
# Out:
# (1303, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        1303 non-null   int64
#  1   Company           1303 non-null   object
#  2   TypeName          1303 non-null   object
#  3   Inches            1303 non-null   float64
#  4   ScreenResolution  1303 non-null   object
#  5   Cpu               1303 non-null   object
#  6   Ram               1303 non-null   object
#  7   Memory            1303 non-null   object
#  8   Gpu               1303 non-null   object
#  9   OpSys             1303 non-null   object
#  10  Weight            1303 non-null   object
#  11  Price             1303 non-null   float64
# dtypes: float64(2), int64(1), object(9)
# memory usage: 122.3+ KB

# %% [markdown]
# ## **Data Summary Report:**

# %%
# check missing values

print('\nMissing values per Column:')
print(df.isnull().sum())
# Out:
# Missing values per Column:
# Unnamed: 0          0
# Company             0
# TypeName            0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %%
# check duplicate rows
print("Number of Duplicate Rows:", df.duplicated().sum())
# Out:
# Number of Duplicate Rows: 0

# %%
# drop unnecessary column 
df.drop(columns=['Unnamed: 0'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8GB            128GB SSD
# 1        Intel Core i5 1.8GHz   8GB  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8GB            256GB SSD
# 3        Intel Core i7 2.7GHz  16GB            512GB SSD
# 4        Intel Core i5 3.1GHz   8GB            256GB SSD
#
#                             Gpu  OpSys  Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS  1.37kg   71378.6832
# 1        Intel HD Graphics 6000  macOS  1.34kg   47895.5232
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   object
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   object
#  10  Price             1303 non-null   float64
# dtypes: float64(2), object(9)
# memory usage: 112.1+ KB

# %%
df['Ram'] = df['Ram'].str.replace('GB','')
df['Weight'] = df['Weight'].str.replace('kg','')

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8            128GB SSD
# 1        Intel Core i5 1.8GHz   8  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8            256GB SSD
# 3        Intel Core i7 2.7GHz  16            512GB SSD
# 4        Intel Core i5 3.1GHz   8            256GB SSD
#
#                             Gpu  OpSys Weight        Price
# 0  Intel Iris Plus Graphics 640  macOS   1.37   71378.6832
# 1        Intel HD Graphics 6000  macOS   1.34   47895.5232
# 2         Intel HD Graphics 620  No OS   1.86   30636.0000
# ...

# %%
# change data type
df['Ram']= df['Ram'].astype('float32')
df['Weight']= df['Weight'].astype('float32')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   float32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
# dtypes: float32(2), float64(2), object(7)
# memory usage: 101.9+ KB

# %% [markdown]
# ## **Data Analysis: Univariate and Bivariate Analysis**

# %% [markdown]
# ### **1. Analysis on "Price" column**

# %%
sns.distplot(df['Price'])
# Out:
# C:\Users\Shivam Shere\AppData\Local\Temp\ipykernel_19200\834922981.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Price'])
# <Axes: xlabel='Price', ylabel='Density'>

# %% [markdown]
# ## **Insights:**
#
# #### **- The data is "skewed"**
# #### **- More laptops, price is low and Less laptops, price is high**

# %% [markdown]
# ### **2. Analysis on "Company" column**

# %%
df['Company'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Company'>

# %% [markdown]
# ## **Insights:**
#
# ### **- 'Dell/Lenovo/HP/ASUS/MSI/Toshiba' these companies laptop have more compare to other companies.**

# %%
## average price for each of company
sns.barplot(x=df['Company'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# ## **Insights:**
#
# ### **- It shows company has impact on laptop prices .**
# ### **- 'Razer' company laptop has highest prices than other companies.**

# %% [markdown]
# ### **3. Analysis on "TypeName" column**

# %%
df['TypeName'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='TypeName'>

# %% [markdown]
# ## **Insights:**
#
# ### **- There are 6 types of laptops.**
# ### **- 'Notebook' is highly selled type of laptop.**

# %%
## average price for each type of laptop
sns.barplot(x=df['TypeName'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# ## **Insights:**
#
# ### **- 'Workstation/Gaming/Ultrabook' types of laptop has highest prices than other.**

# %% [markdown]
# ### **4. Analysis on "Inches" column**

# %%
sns.distplot(df['Inches'])
# Out:
# C:\Users\Shivam Shere\AppData\Local\Temp\ipykernel_19200\1439577752.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Inches'])
# <Axes: xlabel='Inches', ylabel='Density'>

# %% [markdown]
# ## **Insights:**
#
# ### **The values are categorical but not continues**

# %%
sns.scatterplot(x=df['Inches'],y=df['Price'])
# Out:
# <Axes: xlabel='Inches', ylabel='Price'>

# %% [markdown]
# ## **Insights:**
#
# ### **- The laptop size increases, Price increases.**
# ### **- There is correlation but it hasn't strong.**

# %% [markdown]
# ### **5. Analysis on "Screen Resolution" column**

# %%
df['ScreenResolution'].value_counts()
# Out:
# ScreenResolution
# Full HD 1920x1080                                507
# 1366x768                                         281
# IPS Panel Full HD 1920x1080                      230
# IPS Panel Full HD / Touchscreen 1920x1080         53
# Full HD / Touchscreen 1920x1080                   47
# 1600x900                                          23
# Touchscreen 1366x768                              16
# Quad HD+ / Touchscreen 3200x1800                  15
# IPS Panel 4K Ultra HD 3840x2160                   12
# IPS Panel 4K Ultra HD / Touchscreen 3840x2160     11
# 4K Ultra HD / Touchscreen 3840x2160               10
# IPS Panel 1366x768                                 7
# Touchscreen 2560x1440                              7
# 4K Ultra HD 3840x2160                              7
# IPS Panel Retina Display 2304x1440                 6
# IPS Panel Retina Display 2560x1600                 6
# Touchscreen 2256x1504                              6
# ...

# %% [markdown]
# ## **Insights:**
#
# ### **- In each type we get resolution values like "1920x1080".**
# ### **- We need to do Feature Extraction like IPS Panel/ touchscreen,etc for the entire dataset.**

# %% [markdown]
# ## **Feature Engineering:**

# %%
##Make a new column as 'Touchscreen' based on ScreenResolution 
df['Touchscreen'] = df['ScreenResolution'].apply(lambda x:1 if 'Touchscreen' in x else 0)

# %%
df.sample(5)
# Out:
#     Company   TypeName  Inches             ScreenResolution  \
# 237    Asus   Notebook    15.6            Full HD 1920x1080
# 824  Lenovo  Ultrabook    14.0  IPS Panel Full HD 1920x1080
# 83   Lenovo   Notebook    15.6            Full HD 1920x1080
# 198      HP     Gaming    17.3  IPS Panel Full HD 1920x1080
# 323      HP   Notebook    15.6   IPS Panel Full HD 1366x768
#
#                                  Cpu   Ram                Memory  \
# 237  AMD A10-Series A10-9620P 2.5GHz   4.0  128GB SSD +  1TB HDD
# 824       Intel Core i5 7200U 2.5GHz   8.0   256GB Flash Storage
# 83         AMD A6-Series 9220 2.5GHz   4.0             128GB SSD
# 198      Intel Core i7 7700HQ 2.8GHz  16.0  256GB SSD +  1TB HDD
# 323       Intel Core i7 8550U 1.8GHz   8.0               1TB HDD
#
#                          Gpu       OpSys  Weight     Price  Touchscreen
# 237       AMD Radeon R5 M430  Windows 10    2.20  30636.00            0
# ...

# %%
df['Touchscreen'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Touchscreen'>

# %% [markdown]
# ## **Insights:**
#
# ### **- There are only 200-Touchscreen laptops.**

# %%
sns.barplot(x=df['Touchscreen'],y=df['Price'])
# Out:
# <Axes: xlabel='Touchscreen', ylabel='Price'>

# %% [markdown]
# ## **Insights:**
#
# ### **- Touchscreen laptops has higher prices than Non-Touchscreen laptops.**

# %%
##Make a new column as 'IPS' based on ScreenResolution 
df['IPS'] = df['ScreenResolution'].apply(lambda x:1 if 'IPS' in x else 0)

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8.0            128GB SSD
# 1        Intel Core i5 1.8GHz   8.0  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8.0            256GB SSD
# 3        Intel Core i7 2.7GHz  16.0            512GB SSD
# 4        Intel Core i5 3.1GHz   8.0            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# ...

# %%
df['IPS'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='IPS'>

# %% [markdown]
# ## **Insights:**
#
# ### **- The laptops which have 'no IPS display' has more frequency than laptops having IPS display.**

# %%
sns.barplot(x=df['IPS'], y=df['Price'])
# Out:
# <Axes: xlabel='IPS', ylabel='Price'>

# %% [markdown]
# ## **Insights:**
#
# ### **- The laptops having 'IPS display' has more price than laptops having no IPS display.**

# %%
##Make a new column as 'X' and 'Y' Resolutions based on ScreenResolution 
new= df['ScreenResolution'].str.split('x', n=1, expand=True)

# %%
df['X_res']= new[0]
df['Y_res']= new[1]

# %%
df.sample(5)
# Out:
#      Company   TypeName  Inches              ScreenResolution  \
# 288   Lenovo     Gaming    15.6   IPS Panel Full HD 1920x1080
# 469   Lenovo  Ultrabook    14.0  IPS Panel Quad HD+ 2560x1440
# 80      Dell  Ultrabook    15.6   IPS Panel Full HD 1920x1080
# 1115    Dell  Ultrabook    13.3             Full HD 1920x1080
# 310   Lenovo   Notebook    13.3   IPS Panel Full HD 1920x1080
#
#                               Cpu   Ram                Memory  \
# 288   Intel Core i7 7700HQ 2.8GHz  16.0  256GB SSD +  1TB HDD
# 469    Intel Core i7 6600U 2.6GHz  12.0             256GB SSD
# 80     Intel Core i5 8250U 1.6GHz   8.0             256GB SSD
# 1115   Intel Core i7 7560U 2.4GHz   8.0             256GB SSD
# 310    Intel Core i5 7200U 2.5GHz   8.0             256GB SSD
#
#                                Gpu       OpSys  Weight       Price  \
# 288     Nvidia GeForce GTX 1050 Ti  Windows 10    2.50  62817.1200
# 469          Intel HD Graphics 520  Windows 10    1.40  98994.2400
# ...

# %%
##regular expression to extract only resolution value
df['X_res'] = df['X_res'].str.replace(',','').str.findall(r'(\d+\.?\d+)').apply (lambda x: x[0])

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8.0            128GB SSD
# 1        Intel Core i5 1.8GHz   8.0  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8.0            256GB SSD
# 3        Intel Core i7 2.7GHz  16.0            512GB SSD
# 4        Intel Core i5 3.1GHz   8.0            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# ...

# %%
##change data type
df['X_res'] = df['X_res'].astype('int')
df['Y_res'] = df['Y_res'].astype('int')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Company           1303 non-null   object
#  1   TypeName          1303 non-null   object
#  2   Inches            1303 non-null   float64
#  3   ScreenResolution  1303 non-null   object
#  4   Cpu               1303 non-null   object
#  5   Ram               1303 non-null   float32
#  6   Memory            1303 non-null   object
#  7   Gpu               1303 non-null   object
#  8   OpSys             1303 non-null   object
#  9   Weight            1303 non-null   float32
#  10  Price             1303 non-null   float64
#  11  Touchscreen       1303 non-null   int64
#  12  IPS               1303 non-null   int64
#  13  X_res             1303 non-null   int64
#  14  Y_res             1303 non-null   int64
# dtypes: float32(2), float64(2), int64(4), object(7)
# ...

# %% [markdown]
# ## **Correlation Findings:**

# %%
## correlate with price with some features
corr_matrix = df[['Price', 'Inches', 'Ram', 'Weight', 'Touchscreen', 'IPS', 'X_res', 'Y_res']].corr()

# Show correlation of Price with others
print(corr_matrix['Price'])
# Out:
# Price          1.000000
# Inches         0.068197
# Ram            0.743007
# Weight         0.210370
# Touchscreen    0.191226
# IPS            0.252208
# X_res          0.556529
# Y_res          0.552809
# Name: Price, dtype: float64

# %% [markdown]
# ## **Insights:**
#
# ### **- There is high correlation between 'Ram/X_res/Y_res' column with respect to "Price" of laptops.**
# ### **- If Resolution is increased then Price is also increased.**

# %%
# Create 'ppi'(pixel per inches) based on "X_res/Y_res/Inches"columns
df['ppi'] = ((df['X_res']**2 + df['Y_res']**2)**0.5 / df['Inches']).astype('float32')

# %%
df.head()
# Out:
#   Company   TypeName  Inches                    ScreenResolution  \
# 0   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
# 1   Apple  Ultrabook    13.3                            1440x900
# 2      HP   Notebook    15.6                   Full HD 1920x1080
# 3   Apple  Ultrabook    15.4  IPS Panel Retina Display 2880x1800
# 4   Apple  Ultrabook    13.3  IPS Panel Retina Display 2560x1600
#
#                           Cpu   Ram               Memory  \
# 0        Intel Core i5 2.3GHz   8.0            128GB SSD
# 1        Intel Core i5 1.8GHz   8.0  128GB Flash Storage
# 2  Intel Core i5 7200U 2.5GHz   8.0            256GB SSD
# 3        Intel Core i7 2.7GHz  16.0            512GB SSD
# 4        Intel Core i5 3.1GHz   8.0            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# ...

# %%
df[['X_res', 'Y_res', 'Inches', 'ppi']].head()
# Out:
#    X_res  Y_res  Inches         ppi
# 0   2560   1600    13.3  226.983002
# 1   1440    900    13.3  127.677940
# 2   1920   1080    15.6  141.212006
# 3   2880   1800    15.4  220.534622
# 4   2560   1600    13.3  226.983002

# %%
# Correlation of Price with new set of features 
corr_matrix_ppi = df[['Price', 'Inches', 'Ram', 'Weight', 'Touchscreen', 'IPS', 'X_res', 'Y_res', 'ppi']].corr()

print(corr_matrix_ppi['Price'])
# Out:
# Price          1.000000
# Inches         0.068197
# Ram            0.743007
# Weight         0.210370
# Touchscreen    0.191226
# IPS            0.252208
# X_res          0.556529
# Y_res          0.552809
# ppi            0.473487
# Name: Price, dtype: float64

# %% [markdown]
# ## **Insights:**
#
# ### **- There is high correlation between 'Ram/X_res/Y_res' column with respect to "Price" of laptops.**

# %%
# Drop unnecessary columns
df.drop(columns=['ScreenResolution', 'Inches', 'X_res', 'Y_res'], inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu   Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz   8.0            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz   8.0  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz   8.0            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz  16.0            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz   8.0            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           ppi
# 0  226.983002
# ...

# %%
# Verify remaining columns and their dtypes
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Company      1303 non-null   object
#  1   TypeName     1303 non-null   object
#  2   Cpu          1303 non-null   object
#  3   Ram          1303 non-null   float32
#  4   Memory       1303 non-null   object
#  5   Gpu          1303 non-null   object
#  6   OpSys        1303 non-null   object
#  7   Weight       1303 non-null   float32
#  8   Price        1303 non-null   float64
#  9   Touchscreen  1303 non-null   int64
#  10  IPS          1303 non-null   int64
#  11  ppi          1303 non-null   float32
# dtypes: float32(3), float64(1), int64(2), object(6)
# memory usage: 107.0+ KB
# None

# %% [markdown]
# ### **6. Analysis on "CPU" column**

# %%
df['Cpu'].value_counts()
# Out:
# Cpu
# Intel Core i5 7200U 2.5GHz       190
# Intel Core i7 7700HQ 2.8GHz      146
# Intel Core i7 7500U 2.7GHz       134
# Intel Core i7 8550U 1.8GHz        73
# Intel Core i5 8250U 1.6GHz        72
#                                 ...
# Intel Core i5 7200U 2.70GHz        1
# Intel Core M M7-6Y75 1.2GHz        1
# Intel Core M 6Y54 1.1GHz           1
# AMD E-Series 9000 2.2GHz           1
# Samsung Cortex A72&A53 2.0GHz      1
# Name: count, Length: 118, dtype: int64

# %% [markdown]
# ## **Insights:**
#
# ### **- There are total '118' different processors categories of Cpu.**
#
# ### **-The 'Intel Core i5 7200U 2.5GHz'processor has maximum count.**

# %%
##regular expression for extract first 3 words:

df['Cpu Name'] = df['Cpu'].apply(lambda x:" ".join(x.split()[0:3]))

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu   Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz   8.0            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz   8.0  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz   8.0            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz  16.0            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz   8.0            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
#           ppi       Cpu Name
# ...

# %%
## make function to return values processors name:

def fetch_processor(text):
    if text == 'Intel Core i7' or text == 'Intel Core i5' or text == 'Intel Core i3':
        return text
    else:
        if text.split()[0] == 'Intel':
            return 'Other Intel Processor'
        else:
            return 'AMD Processor'

# %%
# Create 'Cpu brand'column based on "Cpu Name"

df['Cpu brand'] = df['Cpu Name'].apply(fetch_processor)

# %%
df.head()
# Out:
#   Company   TypeName                         Cpu   Ram               Memory  \
# 0   Apple  Ultrabook        Intel Core i5 2.3GHz   8.0            128GB SSD
# 1   Apple  Ultrabook        Intel Core i5 1.8GHz   8.0  128GB Flash Storage
# 2      HP   Notebook  Intel Core i5 7200U 2.5GHz   8.0            256GB SSD
# 3   Apple  Ultrabook        Intel Core i7 2.7GHz  16.0            512GB SSD
# 4   Apple  Ultrabook        Intel Core i5 3.1GHz   8.0            256GB SSD
#
#                             Gpu  OpSys  Weight        Price  Touchscreen  IPS  \
# 0  Intel Iris Plus Graphics 640  macOS    1.37   71378.6832            0    1
# 1        Intel HD Graphics 6000  macOS    1.34   47895.5232            0    0
# 2         Intel HD Graphics 620  No OS    1.86   30636.0000            0    0
# 3            AMD Radeon Pro 455  macOS    1.83  135195.3360            0    1
# 4  Intel Iris Plus Graphics 650  macOS    1.37   96095.8080            0    1
#
# ...

# %%
df['Cpu brand'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Cpu brand'>

# %% [markdown]
# ## **Insights:**
#
# ### **-The 'Intel Core i7'processor has maximum count by adding different generation of processors.**

# %%
## average price for each type of Cpu brand
sns.barplot(x=df['Cpu brand'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# ## **Insights:**
#
# ### **-The price of laptop depends on Cpu brand.**

# %%
# Drop unnecessary columns
df.drop(columns=['Cpu','Cpu Name'], inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName   Ram               Memory                           Gpu  \
# 0   Apple  Ultrabook   8.0            128GB SSD  Intel Iris Plus Graphics 640
# 1   Apple  Ultrabook   8.0  128GB Flash Storage        Intel HD Graphics 6000
# 2      HP   Notebook   8.0            256GB SSD         Intel HD Graphics 620
# 3   Apple  Ultrabook  16.0            512GB SSD            AMD Radeon Pro 455
# 4   Apple  Ultrabook   8.0            256GB SSD  Intel Iris Plus Graphics 650
#
#    OpSys  Weight        Price  Touchscreen  IPS         ppi      Cpu brand
# 0  macOS    1.37   71378.6832            0    1  226.983002  Intel Core i5
# 1  macOS    1.34   47895.5232            0    0  127.677940  Intel Core i5
# 2  No OS    1.86   30636.0000            0    0  141.212006  Intel Core i5
# 3  macOS    1.83  135195.3360            0    1  220.534622  Intel Core i7
# 4  macOS    1.37   96095.8080            0    1  226.983002  Intel Core i5

# %%
# Verify remaining columns and their dtypes
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Company      1303 non-null   object
#  1   TypeName     1303 non-null   object
#  2   Ram          1303 non-null   float32
#  3   Memory       1303 non-null   object
#  4   Gpu          1303 non-null   object
#  5   OpSys        1303 non-null   object
#  6   Weight       1303 non-null   float32
#  7   Price        1303 non-null   float64
#  8   Touchscreen  1303 non-null   int64
#  9   IPS          1303 non-null   int64
#  10  ppi          1303 non-null   float32
#  11  Cpu brand    1303 non-null   object
# dtypes: float32(3), float64(1), int64(2), object(6)
# memory usage: 107.0+ KB
# None

# %% [markdown]
# ### **7. Analysis on "Ram" column**

# %%
df['Ram'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Ram'>

# %% [markdown]
# ## **Insights:**
#
# ### **-The "8 GB" Ram is highly preffered.**

# %%
## average price for each type of Ram
sns.barplot(x=df['Ram'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# ## **Insights:**
#
# ### **- When the Ram is increased the price is also increased.**

# %% [markdown]
# ### **8. Analysis on "Memory" column**

# %%
df['Memory'].value_counts()
# Out:
# Memory
# 256GB SSD                        412
# 1TB HDD                          223
# 500GB HDD                        132
# 512GB SSD                        118
# 128GB SSD +  1TB HDD              94
# 128GB SSD                         76
# 256GB SSD +  1TB HDD              73
# 32GB Flash Storage                38
# 2TB HDD                           16
# 64GB Flash Storage                15
# 1TB SSD                           14
# 512GB SSD +  1TB HDD              14
# 256GB SSD +  2TB HDD              10
# 1.0TB Hybrid                       9
# 256GB Flash Storage                8
# 16GB Flash Storage                 7
# 32GB SSD                           6
# 180GB SSD                          5
# 128GB Flash Storage                4
# 16GB SSD                           3
# 512GB SSD +  2TB HDD               3
# 128GB SSD +  2TB HDD               2
# 256GB SSD +  256GB SSD             2
# 512GB Flash Storage                2
# 1TB SSD +  1TB HDD                 2
# ...

# %% [markdown]
# ## **Insights:**
#
# ### **- There are multiple categories along with variations.**
#
# ### **- We need to transform Memory column and make new columns that shows each different values.**

# %%
# clean Memory column
df['Memory'] = df['Memory'].astype(str).replace(r'\.0', '', regex=True)
df['Memory'] = df['Memory'].str.replace('GB', '', regex=True)
df['Memory'] = df['Memory'].str.replace('TB', '000', regex=True)

# split into two parts
new = df['Memory'].str.split('+', n=1, expand=True)
df['first'] = new[0].str.strip()
df['second'] = new[1].fillna('0').str.strip()

# identify storage type
df['Layer1HDD'] = df['first'].apply(lambda x: 1 if 'HDD' in x else 0)
df['Layer1SSD'] = df['first'].apply(lambda x: 1 if 'SSD' in x else 0)
df['Layer1Hybrid'] = df['first'].apply(lambda x: 1 if 'Hybrid' in x else 0)
df['Layer1Flash_Storage'] = df['first'].apply(lambda x: 1 if 'Flash Storage' in x else 0)

df['Layer2HDD'] = df['second'].apply(lambda x: 1 if 'HDD' in x else 0)
df['Layer2SSD'] = df['second'].apply(lambda x: 1 if 'SSD' in x else 0)
df['Layer2Hybrid'] = df['second'].apply(lambda x: 1 if 'Hybrid' in x else 0)
df['Layer2Flash_Storage'] = df['second'].apply(lambda x: 1 if 'Flash Storage' in x else 0)

# extract numbers 
df['first'] = df['first'].str.extract(r'(\d+)').fillna(0).astype(int)
df['second'] = df['second'].str.extract(r'(\d+)').fillna(0).astype(int)

# compute storage in GB
df['HDD'] = df['first']*df['Layer1HDD'] + df['second']*df['Layer2HDD']
df['SSD'] = df['first']*df['Layer1SSD'] + df['second']*df['Layer2SSD']
df['Hybrid'] = df['first']*df['Layer1Hybrid'] + df['second']*df['Layer2Hybrid']
df['Flash_Storage'] = df['first']*df['Layer1Flash_Storage'] + df['second']*df['Layer2Flash_Storage']

# drop helpers
df.drop(columns=['first','second','Layer1HDD','Layer1SSD','Layer1Hybrid','Layer1Flash_Storage',
                 'Layer2HDD','Layer2SSD','Layer2Hybrid','Layer2Flash_Storage'], inplace=True)

# %% [markdown]
# ## **Insights:**
#
# ### **- Create a new columns and extract "HDD/SSD/Hybrid/Flash_Storage" values from "Memory".**

# %%
df.sample(5)
# Out:
#      Company   TypeName   Ram               Memory                    Gpu  \
# 1215    Acer    Netbook   2.0               32 SSD      Intel HD Graphics
# 1117   Razer  Ultrabook   8.0              256 SSD  Intel HD Graphics 520
# 1024    Dell   Notebook   8.0              500 HDD  Intel HD Graphics 520
# 978       HP   Notebook   6.0             1000 HDD  Intel HD Graphics 620
# 372     Asus     Gaming  16.0  256 SSD +  1000 HDD      AMD Radeon RX 580
#
#            OpSys  Weight        Price  Touchscreen  IPS         ppi  \
# 1215   Chrome OS    1.30    9270.7200            0    0  135.094208
# 1117  Windows 10    1.25   54825.1200            1    0  352.465149
# 1024  Windows 10    2.09   55754.3232            0    0  141.212006
# 978   Windows 10    2.04   30849.1200            0    0  100.454666
# 372   Windows 10    3.25  117162.7200            0    1  127.335678
#
#                   Cpu brand   HDD  SSD  Hybrid  Flash_Storage
# ...

# %%
df.drop(columns=['Memory'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName   Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook   8.0  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook   8.0        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook   8.0         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook  16.0            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook   8.0  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  IPS         ppi      Cpu brand  HDD  SSD  Hybrid  \
# 0   71378.6832            0    1  226.983002  Intel Core i5    0  128       0
# 1   47895.5232            0    0  127.677940  Intel Core i5    0    0       0
# 2   30636.0000            0    0  141.212006  Intel Core i5    0  256       0
# 3  135195.3360            0    1  220.534622  Intel Core i7    0  512       0
# 4   96095.8080            0    1  226.983002  Intel Core i5    0  256       0
#
#    Flash_Storage
# 0              0
# 1            128
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1303 entries, 0 to 1302
# Data columns (total 15 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Company        1303 non-null   object
#  1   TypeName       1303 non-null   object
#  2   Ram            1303 non-null   float32
#  3   Gpu            1303 non-null   object
#  4   OpSys          1303 non-null   object
#  5   Weight         1303 non-null   float32
#  6   Price          1303 non-null   float64
#  7   Touchscreen    1303 non-null   int64
#  8   IPS            1303 non-null   int64
#  9   ppi            1303 non-null   float32
#  10  Cpu brand      1303 non-null   object
#  11  HDD            1303 non-null   int64
#  12  SSD            1303 non-null   int64
#  13  Hybrid         1303 non-null   int64
#  14  Flash_Storage  1303 non-null   int64
# dtypes: float32(3), float64(1), int64(6), object(5)
# memory usage: 137.6+ KB

# %%
## correlate with price with some features
corr_matrix = df[['Price', 'Ram', 'Weight', 'Touchscreen', 'IPS', 'ppi','HDD','SSD','Hybrid','Flash_Storage']].corr()

# Show correlation of Price with others
print(corr_matrix['Price'])
# Out:
# Price            1.000000
# Ram              0.743007
# Weight           0.210370
# Touchscreen      0.191226
# IPS              0.252208
# ppi              0.473487
# HDD             -0.096441
# SSD              0.670799
# Hybrid           0.007989
# Flash_Storage   -0.040511
# Name: Price, dtype: float64

# %% [markdown]
# ## **Insights:**
#
# ### **- 'SSD' and 'Ram' has Strong correlation with Price**

# %%
df.drop(columns=['Hybrid','Flash_Storage'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName   Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook   8.0  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook   8.0        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook   8.0         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook  16.0            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook   8.0  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  IPS         ppi      Cpu brand  HDD  SSD
# 0   71378.6832            0    1  226.983002  Intel Core i5    0  128
# 1   47895.5232            0    0  127.677940  Intel Core i5    0    0
# 2   30636.0000            0    0  141.212006  Intel Core i5    0  256
# 3  135195.3360            0    1  220.534622  Intel Core i7    0  512
# 4   96095.8080            0    1  226.983002  Intel Core i5    0  256

# %% [markdown]
# ### **9. Analysis on "Gpu" Column**

# %%
df['Gpu'].value_counts()
# Out:
# Gpu
# Intel HD Graphics 620      281
# Intel HD Graphics 520      185
# Intel UHD Graphics 620      68
# Nvidia GeForce GTX 1050     66
# Nvidia GeForce GTX 1060     48
#                           ...
# Nvidia Quadro M500M          1
# AMD Radeon R7 M360           1
# Nvidia Quadro M3000M         1
# Nvidia GeForce 960M          1
# ARM Mali T860 MP4            1
# Name: count, Length: 110, dtype: int64

# %% [markdown]
# ## **Insights:**
#
# ### **- There are multiple categories along with variations.**
#
# ### **- We need to transform Gpu column and make new columns that shows each different values.**

# %%
df['Gpu brand'] = df['Gpu'].apply(lambda x:x.split()[0])

# %%
df.head()
# Out:
#   Company   TypeName   Ram                           Gpu  OpSys  Weight  \
# 0   Apple  Ultrabook   8.0  Intel Iris Plus Graphics 640  macOS    1.37
# 1   Apple  Ultrabook   8.0        Intel HD Graphics 6000  macOS    1.34
# 2      HP   Notebook   8.0         Intel HD Graphics 620  No OS    1.86
# 3   Apple  Ultrabook  16.0            AMD Radeon Pro 455  macOS    1.83
# 4   Apple  Ultrabook   8.0  Intel Iris Plus Graphics 650  macOS    1.37
#
#          Price  Touchscreen  IPS         ppi      Cpu brand  HDD  SSD  \
# 0   71378.6832            0    1  226.983002  Intel Core i5    0  128
# 1   47895.5232            0    0  127.677940  Intel Core i5    0    0
# 2   30636.0000            0    0  141.212006  Intel Core i5    0  256
# 3  135195.3360            0    1  220.534622  Intel Core i7    0  512
# 4   96095.8080            0    1  226.983002  Intel Core i5    0  256
#
#   Gpu brand
# 0     Intel
# 1     Intel
# 2     Intel
# 3       AMD
# 4     Intel

# %%
df['Gpu brand'].value_counts()
# Out:
# Gpu brand
# Intel     722
# Nvidia    400
# AMD       180
# ARM         1
# Name: count, dtype: int64

# %%
df = df[df['Gpu brand'] != 'ARM']

# %%
df['Gpu brand'].value_counts()
# Out:
# Gpu brand
# Intel     722
# Nvidia    400
# AMD       180
# Name: count, dtype: int64

# %% [markdown]
# ## **Insights:**
#
# ### **- There are 3 major categories of GPU brand.**

# %%
## average price for each type of Ram
sns.barplot(x=df['Gpu brand'],y=df['Price'],estimator=np.median)
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# ## **Insights:**
#
# ### **- The price of laptop depends on Gpu brand.**

# %%
##drop unnecessary column
df.drop(columns=['Gpu'],inplace=True)

# %%
df.head()
# Out:
#   Company   TypeName   Ram  OpSys  Weight        Price  Touchscreen  IPS  \
# 0   Apple  Ultrabook   8.0  macOS    1.37   71378.6832            0    1
# 1   Apple  Ultrabook   8.0  macOS    1.34   47895.5232            0    0
# 2      HP   Notebook   8.0  No OS    1.86   30636.0000            0    0
# 3   Apple  Ultrabook  16.0  macOS    1.83  135195.3360            0    1
# 4   Apple  Ultrabook   8.0  macOS    1.37   96095.8080            0    1
#
#           ppi      Cpu brand  HDD  SSD Gpu brand
# 0  226.983002  Intel Core i5    0  128     Intel
# 1  127.677940  Intel Core i5    0    0     Intel
# 2  141.212006  Intel Core i5    0  256     Intel
# 3  220.534622  Intel Core i7    0  512       AMD
# 4  226.983002  Intel Core i5    0  256     Intel

# %% [markdown]
# ### **10. Analysis on "OpSys" Column**

# %%
df['OpSys'].value_counts()
# Out:
# OpSys
# Windows 10      1072
# No OS             66
# Linux             62
# Windows 7         45
# Chrome OS         26
# macOS             13
# Mac OS X           8
# Windows 10 S       8
# Android            2
# Name: count, dtype: int64

# %% [markdown]
# ## **Insights:**
#
# ### **- There are multiple categories along with variations.**

# %%
## average price for each type of OpSys
sns.barplot(x=df['OpSys'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %%
## make function to return values OpSys name:
def cat_os(inp):
    if inp == 'Windows 10' or inp == 'Windows 7' or inp == 'Windows 10 S':
        return 'Windows'
    
    elif inp == 'macOS' or inp == 'Mac OS X':
        return 'Mac'
    
    else:
        return 'Others/No OS/Linux'

# %%
df['os'] = df['OpSys'].apply(cat_os)

# %%
df.head()
# Out:
#   Company   TypeName   Ram  OpSys  Weight        Price  Touchscreen  IPS  \
# 0   Apple  Ultrabook   8.0  macOS    1.37   71378.6832            0    1
# 1   Apple  Ultrabook   8.0  macOS    1.34   47895.5232            0    0
# 2      HP   Notebook   8.0  No OS    1.86   30636.0000            0    0
# 3   Apple  Ultrabook  16.0  macOS    1.83  135195.3360            0    1
# 4   Apple  Ultrabook   8.0  macOS    1.37   96095.8080            0    1
#
#           ppi      Cpu brand  HDD  SSD Gpu brand                  os
# 0  226.983002  Intel Core i5    0  128     Intel                 Mac
# 1  127.677940  Intel Core i5    0    0     Intel                 Mac
# 2  141.212006  Intel Core i5    0  256     Intel  Others/No OS/Linux
# 3  220.534622  Intel Core i7    0  512       AMD                 Mac
# 4  226.983002  Intel Core i5    0  256     Intel                 Mac

# %%
df.drop(columns=['OpSys'],inplace=True)

# %%
## average price for each type of OpSys
sns.barplot(x=df['os'],y=df['Price'])
plt.xticks(rotation='vertical')
plt.show()

# %% [markdown]
# ## **Insights:**
#
# ### **- "Mac OS" has more price trhan other OS.**

# %% [markdown]
# ### **11. Analysis on "weight" Column**

# %%
sns.distplot(df['Weight'])
# Out:
# C:\Users\Shivam Shere\AppData\Local\Temp\ipykernel_19200\1125578356.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Weight'])
# <Axes: xlabel='Weight', ylabel='Density'>

# %%
sns.scatterplot(x=df['Weight'],y=df['Price'])
# Out:
# <Axes: xlabel='Weight', ylabel='Price'>

# %% [markdown]
# ## **Insights:**
#
# ### **- When Weight of laptop increase, The price is also increase.**

# %%
## correlate with price with some features
corr_matrix = df[['Price', 'Ram', 'Weight', 'Touchscreen', 'IPS', 'ppi','HDD','SSD']].corr()

# Show correlation of Price with others
print(corr_matrix['Price'])
# Out:
# Price          1.000000
# Ram            0.742905
# Weight         0.209867
# Touchscreen    0.192917
# IPS            0.253320
# ppi            0.475368
# HDD           -0.096891
# SSD            0.670660
# Name: Price, dtype: float64

# %%
sns.heatmap(corr_matrix)
# Out:
# <Axes: >

# %% [markdown]
# ### **11. Analysis on "weight" Column**

# %%
sns.distplot(np.log(df['Price']))
# Out:
# C:\Users\Shivam Shere\AppData\Local\Temp\ipykernel_19200\3556049916.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(np.log(df['Price']))
# <Axes: xlabel='Price', ylabel='Density'>

# %%
X = df.drop(columns=['Price'])
y = np.log(df['Price'])

# %%
X
# Out:
#      Company            TypeName   Ram  Weight  Touchscreen  IPS         ppi  \
# 0      Apple           Ultrabook   8.0    1.37            0    1  226.983002
# 1      Apple           Ultrabook   8.0    1.34            0    0  127.677940
# 2         HP            Notebook   8.0    1.86            0    0  141.212006
# 3      Apple           Ultrabook  16.0    1.83            0    1  220.534622
# 4      Apple           Ultrabook   8.0    1.37            0    1  226.983002
# ...      ...                 ...   ...     ...          ...  ...         ...
# 1298  Lenovo  2 in 1 Convertible   4.0    1.80            1    1  157.350510
# 1299  Lenovo  2 in 1 Convertible  16.0    1.30            1    1  276.053528
# 1300  Lenovo            Notebook   2.0    1.50            0    0  111.935204
# 1301      HP            Notebook   6.0    2.19            0    0  100.454666
# 1302    Asus            Notebook   4.0    2.20            0    0  100.454666
#
# ...

# %%
y
# Out:
# 0       11.175755
# 1       10.776777
# 2       10.329931
# 3       11.814476
# 4       11.473101
#           ...
# 1298    10.433899
# 1299    11.288115
# 1300     9.409283
# 1301    10.614129
# 1302     9.886358
# Name: Price, Length: 1302, dtype: float64

# %% [markdown]
# ## **Apply Train/Test Split on data**

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.15,random_state=2)

# %%
X_train
# Out:
#       Company            TypeName   Ram  Weight  Touchscreen  IPS         ppi  \
# 183   Toshiba            Notebook   8.0    2.00            0    0  100.454666
# 1141      MSI              Gaming   8.0    2.40            0    0  141.212006
# 1049     Asus             Netbook   4.0    1.20            0    0  135.094208
# 1020     Dell  2 in 1 Convertible   4.0    2.08            1    1  141.212006
# 878      Dell            Notebook   4.0    2.18            0    0  141.212006
# ...       ...                 ...   ...     ...          ...  ...         ...
# 466      Acer            Notebook   4.0    2.20            0    0  100.454666
# 299      Asus           Ultrabook  16.0    1.63            0    0  141.212006
# 493      Acer            Notebook   8.0    2.20            0    0  100.454666
# 527    Lenovo            Notebook   8.0    2.20            0    0  100.454666
# 1193    Apple           Ultrabook   8.0    0.92            0    1  226.415543
#
# ...

# %% [markdown]
# # **For Categorical column use One hot encoder/ column transformer/ sklearn pipeline to handle column values..**

# %%
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.metrics import r2_score,mean_absolute_error

# %% [markdown]
# # **Algorithms:**

# %%
##importing models
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.ensemble import RandomForestRegressor,ExtraTreesRegressor
from sklearn.svm import SVR

# %% [markdown]
# ## **1.Linear Regresion:**

# %%
# column transformer
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False, drop='first'),[0,1,7,10,11])
],remainder='passthrough')


# linear regression model
step2 = LinearRegression()

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

# train
pipe.fit(X_train,y_train)

# predict
y_pred = pipe.predict(X_test)

# evaluation
print('R2 score:',r2_score(y_test,y_pred))
print('MAE:',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score: 0.8073277435584012
# MAE: 0.21017828080372475

# %%
## Check for difference:
np.exp(0.21017828080372475)
# Out:
# np.float64(1.2338980206796146)

# %% [markdown]
# ## **Insights:**
# #### **- Linear Regression model gives 80% accuracy.**

# %% [markdown]
# ## **2.Ridge Regresion:**

# %%
# column transformer
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False, drop='first'),[0,1,7,10,11])
],remainder='passthrough')

# ridge regression model
step2 = Ridge(alpha=10)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

#train
pipe.fit(X_train,y_train)

#predict
y_pred = pipe.predict(X_test)

#evaluation
print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8127331017700292
# MAE 0.2092680232409919

# %% [markdown]
# ## **Insights:**
# #### **- Ridge Regression model gives 81% accuracy.**

# %% [markdown]
# ## **3.Lasso Regresion:**

# %%
# column transformer
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False, drop='first'),[0,1,7,10,11])
],remainder='passthrough')

#lasso regression model
step2 = Lasso(alpha=0.001)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

#train
pipe.fit(X_train,y_train)

#predict
y_pred = pipe.predict(X_test)

#evaluation
print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8071853931274351
# MAE 0.21114361715169858

# %% [markdown]
# ## **Insights:**
# #### **- Lasso Regression model gives 80% accuracy.**

# %% [markdown]
# ## **4. Support Vector Machine (SVM):**

# %%
# column transformer
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False, drop='first'),[0,1,7,10,11])
],remainder='passthrough')

#SVM model
step2 = SVR(kernel='rbf',C=10000,epsilon=0.1)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

#train
pipe.fit(X_train,y_train)

#predict
y_pred = pipe.predict(X_test)

#evaluation
print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8090031875905177
# MAE 0.2021434919847997

# %% [markdown]
# ## **Insights:**
# #### **- SVM model gives 80% accuracy.**

# %% [markdown]
# ## **5. Random Forest:**

# %%
# column transformer
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False, drop='first'),[0,1,7,10,11])
],remainder='passthrough')

#Random Forest model
step2 = RandomForestRegressor(n_estimators=100,
                              random_state=3,
                              max_samples=0.5,
                              max_features=0.75,
                              max_depth=15)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

#train
pipe.fit(X_train,y_train)

#predict
y_pred = pipe.predict(X_test)

#evaluation
print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8873402378382488
# MAE 0.15860130110457718

# %% [markdown]
# ## **Insights:**
# #### **- Random Forest model gives 88% accuracy.**

# %% [markdown]
# ## **6. Extra Trees: (Random Forest Variation)**

# %%
# column transformer
step1 = ColumnTransformer(transformers=[
    ('col_tnf',OneHotEncoder(sparse_output=False, drop='first'),[0,1,7,10,11])
],remainder='passthrough')

#Extra Trees model
step2 = ExtraTreesRegressor(n_estimators=100,
                              random_state=3,
                              bootstrap=True,
                              max_samples=0.5,
                              max_features=0.75,
                              max_depth=15)

pipe = Pipeline([
    ('step1',step1),
    ('step2',step2)
])

#train
pipe.fit(X_train,y_train)

#predict
y_pred = pipe.predict(X_test)

#evaluation
print('R2 score',r2_score(y_test,y_pred))
print('MAE',mean_absolute_error(y_test,y_pred))
# Out:
# R2 score 0.8850720167552375
# MAE 0.16154538000217084

# %% [markdown]
# ## **Insights:**
# #### **- Extra Trees model gives 88% accuracy.**

# %% [markdown]
# # **Hyper Parameter Tunning**

# %% [markdown]
# ## Ridge Regreesion:

# %%
from sklearn.model_selection import GridSearchCV

# Column transformer 
step1 = ColumnTransformer(transformers=[
    ('col_tnf', OneHotEncoder(sparse_output=False, drop='first'), [0,1,7,10,11])
], remainder='passthrough')

# Ridge model (alpha will be tuned)
step2 = Ridge()

pipe = Pipeline([
    ('step1', step1),
    ('step2', step2)
])

# Define parameter grid 
param_grid = {
    'step2__alpha': [0.001, 0.01, 0.1, 1, 10, 50, 100, 200, 500, 1000]
}

# Grid Search
grid = GridSearchCV(pipe, param_grid, scoring='r2', cv=5, n_jobs=-1, verbose=1)
grid.fit(X_train, y_train)

# Best Parameters
print("Best Parameters:", grid.best_params_)
print("Best CV R2 Score:", grid.best_score_)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# Best Parameters: {'step2__alpha': 0.001}
# Best CV R2 Score: 0.8178998779290367

# %%
# Evaluate on test set
y_pred = grid.predict(X_test)
print("Test R2 score:", r2_score(y_test, y_pred))
print("Test MAE:", mean_absolute_error(y_test, y_pred))
# Out:
# Test R2 score: 0.8073312076361703
# Test MAE: 0.21017708340706917

# %% [markdown]
# ## **Insights:**
# #### **- The before tuning Ridge Regression model is better.**

# %% [markdown]
# ## Lasso Regreesion:

# %%
from sklearn.model_selection import GridSearchCV

# column transformer
step1 = ColumnTransformer(transformers=[
    ('col_tnf', OneHotEncoder(sparse_output=False, drop='first'), [0,1,7,10,11])
], remainder='passthrough')

# lasso regression model
step2 = Lasso(max_iter=10000)   # important: increase max_iter for convergence

pipe = Pipeline([
    ('step1', step1),
    ('step2', step2)
])

# parameter grid for alpha values
param_grid = {
    'step2__alpha': [0.0001, 0.001, 0.01, 0.1, 1, 5, 10, 50, 100]
}

# grid search
grid = GridSearchCV(pipe, param_grid, cv=5, scoring='r2', n_jobs=-1)

grid.fit(X_train, y_train)

# best parameters
print("Best Parameters:", grid.best_params_)

# predict with best model
y_pred = grid.best_estimator_.predict(X_test)
# Out:
# Best Parameters: {'step2__alpha': 0.0001}

# %%
# evaluation
print("Test R2 score:", r2_score(y_test, y_pred))
print("Test MAE:", mean_absolute_error(y_test, y_pred))
# Out:
# Test R2 score: 0.8082917403209389
# Test MAE: 0.20991753340682678

# %% [markdown]
# ## **Insights:**
# #### **- The after tuning, Lasso Regression model is slightly better.**

# %% [markdown]
# ## SVM:

# %%
from sklearn.model_selection import GridSearchCV

# column transformer
step1 = ColumnTransformer(transformers=[
    ('col_tnf', OneHotEncoder(sparse_output=False, drop='first'), [0,1,7,10,11])
], remainder='passthrough')

# SVR model
step2 = SVR()

pipe = Pipeline([
    ('step1', step1),
    ('step2', step2)
])

# hyperparameter grid
param_grid = {
    'step2__C': [1000, 5000, 10000, 20000],
    'step2__epsilon': [0.01, 0.1, 0.5, 1],
    'step2__gamma': ['scale', 'auto', 0.01, 0.1, 1]
}

# grid search
grid = GridSearchCV(pipe, param_grid, cv=3, scoring='r2', n_jobs=-1, verbose=1)
grid.fit(X_train, y_train)

# best parameters
print("Best Parameters:", grid.best_params_)

# predict using best estimator
y_pred = grid.best_estimator_.predict(X_test)
# Out:
# Fitting 3 folds for each of 80 candidates, totalling 240 fits
# Best Parameters: {'step2__C': 10000, 'step2__epsilon': 0.1, 'step2__gamma': 'scale'}

# %%
# evaluation
print("Test R2 score:", r2_score(y_test, y_pred))
print("Test MAE:", mean_absolute_error(y_test, y_pred))
# Out:
# Test R2 score: 0.8090031875905177
# Test MAE: 0.2021434919847997

# %% [markdown]
# ## **Insights:**
# #### **-The results are same before and after tuning.**

# %% [markdown]
# ## Random Forest:

# %%
from sklearn.model_selection import GridSearchCV

# column transformer
step1 = ColumnTransformer(transformers=[
    ('col_tnf', OneHotEncoder(sparse_output=False, drop='first'), [0,1,7,10,11])
], remainder='passthrough')

# random forest model
step2 = RandomForestRegressor(random_state=3)

pipe = Pipeline([
    ('step1', step1),
    ('step2', step2)
])

# hyper parameter grid
param_grid = {
    'step2__n_estimators': [100, 200, 300],
    'step2__max_depth': [10, 15, 20, None],
    'step2__max_features': [0.6, 0.75, 1.0],
    'step2__min_samples_split': [2, 5, 10],
    'step2__min_samples_leaf': [1, 2, 4],
    'step2__max_samples': [0.5, 0.7, None]
}

# grid search
grid = GridSearchCV(pipe, param_grid, cv=3, scoring='r2', n_jobs=-1, verbose=1)
grid.fit(X_train, y_train)

# best parameters
print("Best Parameters:", grid.best_params_)

# predict using best estimator
y_pred = grid.best_estimator_.predict(X_test)
# Out:
# Fitting 3 folds for each of 972 candidates, totalling 2916 fits
# Best Parameters: {'step2__max_depth': 20, 'step2__max_features': 0.6, 'step2__max_samples': None, 'step2__min_samples_leaf': 1, 'step2__min_samples_split': 2, 'step2__n_estimators': 100}

# %%
# evaluation 
print("Test R2 score:", r2_score(y_test, y_pred))
print("Test MAE:", mean_absolute_error(y_test, y_pred))
# Out:
# Test R2 score: 0.8928268704860176
# Test MAE: 0.15234329046850598

# %% [markdown]
# ## **Insights:**
# #### **- Hyperparameter tuning improved the Random Forest model’s accuracy and reduced error.**

# %% [markdown]
# ## Extra Trees:

# %%
from sklearn.model_selection import GridSearchCV

# column transformer
step1 = ColumnTransformer(transformers=[
    ('col_tnf', OneHotEncoder(sparse_output=False, drop='first'), [0,1,7,10,11])
], remainder='passthrough')

# extra Trees model
step2 = ExtraTreesRegressor(random_state=3)

pipe = Pipeline([
    ('step1', step1),
    ('step2', step2)
])

# hyperparameter grid
param_grid = {
    'step2__n_estimators': [100, 200, 300],
    'step2__max_depth': [10, 15, 20, None],
    'step2__max_features': [0.6, 0.75, 1.0],
    'step2__min_samples_split': [2, 5, 10],
    'step2__min_samples_leaf': [1, 2, 4],
    'step2__bootstrap': [True, False],
    'step2__max_samples': [0.5, 0.7, None]
}

# grid search
grid = GridSearchCV(pipe, param_grid, cv=3, scoring='r2', n_jobs=-1, verbose=1)
grid.fit(X_train, y_train)

# best parameters
print("Best Parameters:", grid.best_params_)

# predict using best estimator
y_pred = grid.best_estimator_.predict(X_test)
# Out:
# Fitting 3 folds for each of 1944 candidates, totalling 5832 fits
# d:\Shivam\Laptop_Price_predict\laptop\Lib\site-packages\sklearn\model_selection\_validation.py:516: FitFailedWarning:
# 1944 fits failed out of a total of 5832.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1944 fits failed with the following error:
# Traceback (most recent call last):
#   File "d:\Shivam\Laptop_Price_predict\laptop\Lib\site-packages\sklearn\model_selection\_validation.py", line 859, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "d:\Shivam\Laptop_Price_predict\laptop\Lib\site-packages\sklearn\base.py", line 1365, in wrapper
#     return fit_method(estimator, *args, **kwargs)
# ...

# %%
# evaluation
print("Test R2 score:", r2_score(y_test, y_pred))
print("Test MAE:", mean_absolute_error(y_test, y_pred))
# Out:
# Test R2 score: 0.8855517589132932
# Test MAE: 0.15799654683982242

# %% [markdown]
# ## **Insights:**
# #### **- Hyperparameter tuning slightly improved the Extra Trees model’s accuracy and reduced error.**

# %% [markdown]
# ## **Insights:**
#
# #### **- Random Forest achieved the best improvement after tuning (R² +0.0055, MAE -0.0063)**
#
# #### **- Extra Trees improved slightly after tuning (R² +0.00048, MAE -0.0035)**
#
# #### **- Linear Regression & SVM did not change with tuning.**
#
# #### **- Ridge Regression performed slightly worse after tuning.**
#
# #### **- Lasso Regression improved slightly after tuning.**

# %% [markdown]
# #### **IMP:**
# #### *- The tuned Random Forest model is the best choice for the dataset.*

# %% [markdown]
# ##  **Voting Regressor with Cross-Validation:**

# %%
from sklearn.ensemble import VotingRegressor
from sklearn.model_selection import cross_val_score

# %% [markdown]
# from sklearn.preprocessing import OneHotEncoder, StandardScaler

# %%
# column transformer 
step1 = ColumnTransformer(transformers=[
    ('col_tnf', OneHotEncoder(sparse_output=False, drop='first', handle_unknown='ignore'), [0,1,7,10,11])
], remainder='passthrough')

# tuned models
ridge = Ridge(alpha=10)
lasso = Lasso(alpha=0.001)
svm = SVR(kernel='rbf', C=10000, epsilon=0.1)
rf = RandomForestRegressor(n_estimators=200, random_state=3,
                           max_samples=0.8, max_features=0.8, max_depth=20)
et = ExtraTreesRegressor(n_estimators=200, random_state=3, bootstrap=True,
                         max_samples=0.8, max_features=0.8, max_depth=20)

# voting regressor 
step2 = VotingRegressor([
    ('ridge', ridge), 
    ('lasso', lasso), 
    ('svm', svm), 
    ('rf', rf), 
    ('et', et)
])

pipe_voting = Pipeline([
    ('step1', step1),
    ('step2', step2)
])

# train
pipe_voting.fit(X_train, y_train)

# predict
y_pred_voting = pipe_voting.predict(X_test)


# cross-validation
scores_r2_voting = cross_val_score(pipe_voting, X, y, cv=5, scoring='r2')
scores_mae_voting = cross_val_score(pipe_voting, X, y, cv=5, scoring='neg_mean_absolute_error')
# Out:
# d:\Shivam\Laptop_Price_predict\laptop\Lib\site-packages\sklearn\preprocessing\_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# d:\Shivam\Laptop_Price_predict\laptop\Lib\site-packages\sklearn\preprocessing\_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %%
#evaluate
print("Voting Regressor Results:")
print("Mean R2:", np.mean(scores_r2_voting))
print("Mean MAE:", -np.mean(scores_mae_voting))
# Out:
# Voting Regressor Results:
# Mean R2: 0.8446643739110348
# Mean MAE: 0.1886761194895667

# %% [markdown]
# ##  **Stacking with Cross-Validation:**

# %%
from sklearn.ensemble import StackingRegressor
from sklearn.model_selection import cross_val_score

# %% [markdown]
# from sklearn.preprocessing import OneHotEncoder, StandardScaler

# %%
# column transformer 
step1 = ColumnTransformer(transformers=[
    ('col_tnf', OneHotEncoder(sparse_output=False, drop='first', handle_unknown='ignore'), [0,1,7,10,11])
], remainder='passthrough')

# tuned models
ridge = Ridge(alpha=10)
lasso = Lasso(alpha=0.001)
svm = SVR(kernel='rbf', C=10000, epsilon=0.1)
rf = RandomForestRegressor(n_estimators=200, random_state=3,
                           max_samples=0.8, max_features=0.8, max_depth=20)
et = ExtraTreesRegressor(n_estimators=200, random_state=3, bootstrap=True,
                         max_samples=0.8, max_features=0.8, max_depth=20)


#stacking
step2 = StackingRegressor(
    estimators=[
        ('ridge', ridge),
        ('lasso', lasso),
        ('svm', svm),
        ('rf', rf),
        ('et', et)
    ],
    final_estimator=LinearRegression()
)

pipe_stacking = Pipeline([
    ('step1', step1),
    ('step2', step2)
])

# train
pipe_stacking.fit(X_train, y_train)

# predict
y_pred_stacking = pipe_voting.predict(X_test)

# Cross-validation
scores_r2_stacking = cross_val_score(pipe_stacking, X, y, cv=5, scoring='r2')
scores_mae_stacking = cross_val_score(pipe_stacking, X, y, cv=5, scoring='neg_mean_absolute_error')
# Out:
# d:\Shivam\Laptop_Price_predict\laptop\Lib\site-packages\sklearn\preprocessing\_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# d:\Shivam\Laptop_Price_predict\laptop\Lib\site-packages\sklearn\preprocessing\_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %%
#evaluate
print("Stacking Regressor Results:")
print("Mean R2:", np.mean(scores_r2_stacking))
print("Mean MAE:", -np.mean(scores_mae_stacking))
# Out:
# Stacking Regressor Results:
# Mean R2: 0.8634772059772656
# Mean MAE: 0.17414011647307637

# %%
## Use Ridge with alpha=100 as final estimator for stacking:

# column transformer 
step1 = ColumnTransformer(transformers=[
    ('col_tnf', OneHotEncoder(sparse_output=False, drop='first', handle_unknown='ignore'), [0,1,7,10,11])
], remainder='passthrough')

# tuned models
ridge = Ridge(alpha=10)
lasso = Lasso(alpha=0.001)
svm = SVR(kernel='rbf', C=10000, epsilon=0.1)
rf = RandomForestRegressor(n_estimators=200, random_state=3,
                           max_samples=0.8, max_features=0.8, max_depth=20)
et = ExtraTreesRegressor(n_estimators=200, random_state=3, bootstrap=True,
                         max_samples=0.8, max_features=0.8, max_depth=20)


#stacking
step2 = StackingRegressor(
    estimators=[
        ('ridge', ridge),
        ('lasso', lasso),
        ('svm', svm),
        ('rf', rf),
        ('et', et)
    ],
    final_estimator=Ridge(alpha=100)
)

pipe_stacking = Pipeline([
    ('step1', step1),
    ('step2', step2)
])

# train
pipe_stacking.fit(X_train, y_train)

# predict
y_pred_stacking = pipe_voting.predict(X_test)

# Cross-validation
scores_r2_stacking = cross_val_score(pipe_stacking, X, y, cv=5, scoring='r2')
scores_mae_stacking = cross_val_score(pipe_stacking, X, y, cv=5, scoring='neg_mean_absolute_error')
# Out:
# d:\Shivam\Laptop_Price_predict\laptop\Lib\site-packages\sklearn\preprocessing\_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# d:\Shivam\Laptop_Price_predict\laptop\Lib\site-packages\sklearn\preprocessing\_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(

# %%
#evaluate
print("Stacking Regressor Results:")
print("Mean R2:", np.mean(scores_r2_stacking))
print("Mean MAE:", -np.mean(scores_mae_stacking))
# Out:
# Stacking Regressor Results:
# Mean R2: 0.8501583950497975
# Mean MAE: 0.18567324040740507

# %% [markdown]
# ## **Insights:**
# #### **- Random Forest (after hyperparameter tuning) gives highest R² = 0.8928 and lowest MAE = 0.1523.**
#
# #### **- Voting and Stacking process doesn't improve the accuracy.**

# %%
from sklearn.model_selection import GridSearchCV

# column transformer
step1 = ColumnTransformer(transformers=[
    ('col_tnf', OneHotEncoder(sparse_output=False, drop='first'), [0,1,7,10,11])
], remainder='passthrough')

# random forest model
step2 = RandomForestRegressor(random_state=3)

pipe = Pipeline([
    ('step1', step1),
    ('step2', step2)
])

# hyper parameter grid
param_grid = {
    'step2__n_estimators': [100, 200, 300],
    'step2__max_depth': [10, 15, 20, None],
    'step2__max_features': [0.6, 0.75, 1.0],
    'step2__min_samples_split': [2, 5, 10],
    'step2__min_samples_leaf': [1, 2, 4],
    'step2__max_samples': [0.5, 0.7, None]
}

# grid search
grid = GridSearchCV(pipe, param_grid, cv=3, scoring='r2', n_jobs=-1, verbose=1)
grid.fit(X_train, y_train)

# best parameters
print("Best Parameters:", grid.best_params_)

# predict using best estimator
y_pred = grid.best_estimator_.predict(X_test)

# evaluation 
print("Test R2 score:", r2_score(y_test, y_pred))
print("Test MAE:", mean_absolute_error(y_test, y_pred))
# Out:
# Fitting 3 folds for each of 972 candidates, totalling 2916 fits
# Best Parameters: {'step2__max_depth': 20, 'step2__max_features': 0.6, 'step2__max_samples': None, 'step2__min_samples_leaf': 1, 'step2__min_samples_split': 2, 'step2__n_estimators': 100}
# Test R2 score: 0.8928268704860176
# Test MAE: 0.15234329046850598

# %% [markdown]
# # **Exporting model:**

# %%
# saving random forest model
import pickle

with open('rf_best_model.pkl', 'wb') as f:
    pickle.dump(grid.best_estimator_, f)

# %%
#saving data frame
import pickle

with open('df.pkl', 'wb') as f:
    pickle.dump(df, f)

# %%
df
# Out:
#      Company            TypeName   Ram  Weight        Price  Touchscreen  IPS  \
# 0      Apple           Ultrabook   8.0    1.37   71378.6832            0    1
# 1      Apple           Ultrabook   8.0    1.34   47895.5232            0    0
# 2         HP            Notebook   8.0    1.86   30636.0000            0    0
# 3      Apple           Ultrabook  16.0    1.83  135195.3360            0    1
# 4      Apple           Ultrabook   8.0    1.37   96095.8080            0    1
# ...      ...                 ...   ...     ...          ...          ...  ...
# 1298  Lenovo  2 in 1 Convertible   4.0    1.80   33992.6400            1    1
# 1299  Lenovo  2 in 1 Convertible  16.0    1.30   79866.7200            1    1
# 1300  Lenovo            Notebook   2.0    1.50   12201.1200            0    0
# 1301      HP            Notebook   6.0    2.19   40705.9200            0    0
# 1302    Asus            Notebook   4.0    2.20   19660.3200            0    0
#
# ...

# %%
X_train
# Out:
#       Company            TypeName   Ram  Weight  Touchscreen  IPS         ppi  \
# 183   Toshiba            Notebook   8.0    2.00            0    0  100.454666
# 1141      MSI              Gaming   8.0    2.40            0    0  141.212006
# 1049     Asus             Netbook   4.0    1.20            0    0  135.094208
# 1020     Dell  2 in 1 Convertible   4.0    2.08            1    1  141.212006
# 878      Dell            Notebook   4.0    2.18            0    0  141.212006
# ...       ...                 ...   ...     ...          ...  ...         ...
# 466      Acer            Notebook   4.0    2.20            0    0  100.454666
# 299      Asus           Ultrabook  16.0    1.63            0    0  141.212006
# 493      Acer            Notebook   8.0    2.20            0    0  100.454666
# 527    Lenovo            Notebook   8.0    2.20            0    0  100.454666
# 1193    Apple           Ultrabook   8.0    0.92            0    1  226.415543
#
# ...
